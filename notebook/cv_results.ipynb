# %%
import os
import sys

# Init project path
PROJECT_DIR = os.getcwd() + "/../"
sys.path.insert(0, PROJECT_DIR)
# %load_ext autoreload
# %autoreload 2

# %%
from db import table_load
result = table_load("cv_result_1")
train = table_load("cv_train_1")
test = table_load("cv_test_1")

# %%
import pandas as pd
pd.concat([result, test], axis=1)
# Out:
#        level_0  predicted  real  difference  difference_abs  passenger_id  \
# index
# 6            0   0.236623     0    0.236623        0.236623             7
# 8            1   0.293294     1   -0.706706        0.706706             9
# 12           2   0.194293     0    0.194293        0.194293            13
# 30           3   0.199266     0    0.199266        0.199266            31
# 32           4   0.721785     1   -0.278215        0.278215            33
# ...        ...        ...   ...         ...             ...           ...
# 865        174   0.830103     1   -0.169897        0.169897           866
# 867        175   0.418356     0    0.418356        0.418356           868
# 872        176   0.006362     0    0.006362        0.006362           873
# 874        177   0.851549     1   -0.148451        0.148451           875
# 890        178   0.132144     0    0.132144        0.132144           891
#
# ...
